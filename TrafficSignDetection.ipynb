# %%
import numpy as np
import pandas as pd
import os
import cv2
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from PIL import Image
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.optimizers import Adam
from sklearn.metrics import accuracy_score
np.random.seed(42)
import random

# %%
os.getcwd()
# Out:
# 'F:\\traffic_sign'

# %%
os.chdir("F:/traffic_sign")

# %%
data_dir="F:/traffic_sign"
train_path="Train"
test_path="Test"

img_height=30
img_width=30
channels=3

# %%
num_categories=len(os.listdir(train_path))
num_categories
# Out:
# 43

# %%
classes = { 0:'Speed limit (20km/h)',
            1:'Speed limit (30km/h)', 
            2:'Speed limit (50km/h)', 
            3:'Speed limit (60km/h)', 
            4:'Speed limit (70km/h)', 
            5:'Speed limit (80km/h)', 
            6:'End of speed limit (80km/h)', 
            7:'Speed limit (100km/h)', 
            8:'Speed limit (120km/h)', 
            9:'No passing', 
            10:'No passing veh over 3.5 tons', 
            11:'Right-of-way at intersection', 
            12:'Priority road', 
            13:'Yield', 
            14:'Stop', 
            15:'No vehicles', 
            16:'Veh > 3.5 tons prohibited', 
            17:'No entry', 
            18:'General caution', 
            19:'Dangerous curve left', 
            20:'Dangerous curve right', 
            21:'Double curve', 
            22:'Bumpy road', 
            23:'Slippery road', 
            24:'Road narrows on the right', 
            25:'Road work', 
            26:'Traffic signals', 
            27:'Pedestrians', 
            28:'Children crossing', 
            29:'Bicycles crossing', 
            30:'Beware of ice/snow',
            31:'Wild animals crossing', 
            32:'End speed + passing limits', 
            33:'Turn right ahead', 
            34:'Turn left ahead', 
            35:'Ahead only', 
            36:'Go straight or right', 
            37:'Go straight or left', 
            38:'Keep right', 
            39:'Keep left', 
            40:'Roundabout mandatory', 
            41:'End of no passing', 
            42:'End no passing veh > 3.5 tons' }

# %%
folders=os.listdir(train_path)

train_number=[]
class_num=[]

for folder in folders:
    train_files=os.listdir(train_path + '/' + folder)
    train_number.append(len(train_files))
    class_num.append(classes[int(folder)])
    
print(train_number)

plt.figure(figsize=(21,10))
plt.bar(class_num,train_number)
plt.xticks(class_num,rotation='vertical')
plt.show()
# Out:
# [210, 2220, 2010, 1320, 2100, 2160, 780, 630, 420, 1110, 1200, 210, 2250, 360, 330, 390, 510, 270, 1500, 600, 240, 540, 270, 1410, 450, 780, 240, 689, 420, 1200, 390, 210, 2070, 300, 1980, 360, 240, 240, 1860, 420, 1440, 1410, 1470]

# %%
test=pd.read_csv(data_dir + '/Test.csv')
test.head()
# Out:
#    Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId            Path
# 0     53      54       6       5      48      49       16  Test/00000.png
# 1     42      45       5       5      36      40        1  Test/00001.png
# 2     48      52       6       6      43      47       38  Test/00002.png
# 3     27      29       5       5      22      24       33  Test/00003.png
# 4     60      57       5       5      55      52       11  Test/00004.png

# %%
imgs=test["Path"].values

plt.figure(figsize=(25,25))

for i in range(1,26):
    plt.subplot(5,5,i)
    random_img_path=data_dir + '/' + random.choice(imgs)
    rand_img=cv2.imread(random_img_path)
    plt.imshow(rand_img)

# %%
image_data=[]
image_labels=[]

for i in range(num_categories):
    path=data_dir + '/Train/' + str(i)
    images=os.listdir(path)
    
    for img in images:
        image=cv2.imread(path + '/' + img)
        image_fromarray=Image.fromarray(image,'RGB')
        resize_image=image_fromarray.resize((img_height,img_width))
        image_data.append(np.array(resize_image))
        image_labels.append(i)
        
image_data=np.array(image_data)
image_labels=np.array(image_labels)

print(image_data.shape,image_labels.shape)
# Out:
# (39209, 30, 30, 3) (39209,)

# %%
X_train,X_val,y_train,y_val=train_test_split(image_data,image_labels,test_size=0.3,random_state=0,shuffle=True)

X_train=X_train/255
X_val=X_val/255

print(X_train.shape)
print(X_val.shape)
print(y_train.shape)
print(y_val.shape)
# Out:
# (27446, 30, 30, 3)
# (11763, 30, 30, 3)
# (27446,)
# (11763,)

# %%
y_train=keras.utils.to_categorical(y_train,num_categories)
y_val=keras.utils.to_categorical(y_val,num_categories)

print(y_train.shape)
print(y_val.shape)
# Out:
# (27446, 43)
# (11763, 43)

# %%
model=keras.models.Sequential([
    keras.layers.Conv2D(filters=16,kernel_size=(5,5),activation='relu',input_shape=(img_height,img_width,channels)),
    keras.layers.Conv2D(filters=32,kernel_size=(5,5),activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.BatchNormalization(axis=-1),
    
    keras.layers.Conv2D(filters=64,kernel_size=(5,5),activation='relu'),
    keras.layers.Conv2D(filters=128,kernel_size=(5,5),activation='relu'),
    keras.layers.MaxPool2D(pool_size=(2,2)),
    keras.layers.BatchNormalization(axis=-1),
    
    keras.layers.Flatten(),
    keras.layers.Dense(512,activation='relu'),
    keras.layers.BatchNormalization(axis=-1),
    keras.layers.Dropout(rate=0.5),
    
    keras.layers.Dense(43,activation='softmax')
])

# %%
optimizer=Adam(learning_rate=0.01)

# %%
model.compile(loss='categorical_crossentropy',optimizer=optimizer,metrics=['accuracy'])

# %%
aug=ImageDataGenerator(rotation_range=10,
                       zoom_range=0.15,
                       width_shift_range=0.1,
                       height_shift_range=0.1,
                       shear_range=0.15,
                       horizontal_flip=False,
                       vertical_flip=False,
                       fill_mode="nearest"
                      )

# %%
history=model.fit(aug.flow(X_train,y_train,batch_size=32),epochs=30,validation_data=(X_val,y_val))
# Out:
# Epoch 1/30
# 858/858 [==============================] - 33s 38ms/step - loss: 2.6197 - accuracy: 0.3215 - val_loss: 1.3152 - val_accuracy: 0.6078
# Epoch 2/30
# 858/858 [==============================] - 39s 45ms/step - loss: 0.9252 - accuracy: 0.7086 - val_loss: 2.4902 - val_accuracy: 0.9306
# Epoch 3/30
# 858/858 [==============================] - 35s 41ms/step - loss: 0.5368 - accuracy: 0.8355 - val_loss: 0.4873 - val_accuracy: 0.9172
# Epoch 4/30
# 858/858 [==============================] - 36s 42ms/step - loss: 0.3934 - accuracy: 0.8817 - val_loss: 0.8961 - val_accuracy: 0.9407
# Epoch 5/30
# 858/858 [==============================] - 35s 41ms/step - loss: 0.3318 - accuracy: 0.9022 - val_loss: 0.1096 - val_accuracy: 0.9659
# Epoch 6/30
# 858/858 [==============================] - 35s 41ms/step - loss: 0.2990 - accuracy: 0.9116 - val_loss: 1.7846 - val_accuracy: 0.9827
# Epoch 7/30
# 858/858 [==============================] - 35s 41ms/step - loss: 0.2690 - accuracy: 0.9216 - val_loss: 0.0913 - val_accuracy: 0.9751
# Epoch 8/30
# 858/858 [==============================] - 35s 41ms/step - loss: 0.2456 - accuracy: 0.9306 - val_loss: 0.0828 - val_accuracy: 0.9772
# Epoch 9/30
# 858/858 [==============================] - 35s 41ms/step - loss: 0.2382 - accuracy: 0.9335 - val_loss: 5.9550 - val_accuracy: 0.9831
# Epoch 10/30
# 858/858 [==============================] - 36s 41ms/step - loss: 0.2286 - accuracy: 0.9384 - val_loss: 2.9296 - val_accuracy: 0.9767
# Epoch 11/30
# 858/858 [==============================] - 35s 41ms/step - loss: 0.2109 - accuracy: 0.9448 - val_loss: 0.2448 - val_accuracy: 0.9648
# Epoch 12/30
# 858/858 [==============================] - 35s 41ms/step - loss: 0.2046 - accuracy: 0.9477 - val_loss: 0.5287 - val_accuracy: 0.9877
# Epoch 13/30
# 858/858 [==============================] - 35s 41ms/step - loss: 0.1959 - accuracy: 0.9508 - val_loss: 0.0525 - val_accuracy: 0.9867
# Epoch 14/30
# 858/858 [==============================] - 35s 41ms/step - loss: 0.1873 - accuracy: 0.9550 - val_loss: 5.7784 - val_accuracy: 0.9901
# Epoch 15/30
# 858/858 [==============================] - 35s 41ms/step - loss: 0.1842 - accuracy: 0.9561 - val_loss: 0.8422 - val_accuracy: 0.9872
# Epoch 16/30
# 858/858 [==============================] - 35s 41ms/step - loss: 0.1779 - accuracy: 0.9575 - val_loss: 0.2227 - val_accuracy: 0.9957
# Epoch 17/30
# 858/858 [==============================] - 35s 41ms/step - loss: 0.2282 - accuracy: 0.9500 - val_loss: 0.1503 - val_accuracy: 0.9884
# Epoch 18/30
# 858/858 [==============================] - 35s 41ms/step - loss: 0.1443 - accuracy: 0.9655 - val_loss: 0.0871 - val_accuracy: 0.9910
# Epoch 19/30
# 858/858 [==============================] - 35s 41ms/step - loss: 0.1577 - accuracy: 0.9639 - val_loss: 0.4933 - val_accuracy: 0.9930
# Epoch 20/30
# 858/858 [==============================] - 35s 41ms/step - loss: 0.1561 - accuracy: 0.9661 - val_loss: 1.1927 - val_accuracy: 0.9909
# Epoch 21/30
# 858/858 [==============================] - 36s 41ms/step - loss: 0.1528 - accuracy: 0.9670 - val_loss: 0.0657 - val_accuracy: 0.9872
# Epoch 22/30
# 858/858 [==============================] - 35s 41ms/step - loss: 0.1653 - accuracy: 0.9635 - val_loss: 12.7831 - val_accuracy: 0.9796
# Epoch 23/30
# 858/858 [==============================] - 35s 41ms/step - loss: 0.1461 - accuracy: 0.9692 - val_loss: 1249.7533 - val_accuracy: 0.9767
# Epoch 24/30
# 858/858 [==============================] - 35s 41ms/step - loss: 0.1605 - accuracy: 0.9683 - val_loss: 0.3413 - val_accuracy: 0.9898
# Epoch 25/30
# 858/858 [==============================] - 35s 41ms/step - loss: 0.1521 - accuracy: 0.9711 - val_loss: 0.0527 - val_accuracy: 0.9946
# Epoch 26/30
# 858/858 [==============================] - 35s 41ms/step - loss: 0.1701 - accuracy: 0.9670 - val_loss: 0.0242 - val_accuracy: 0.9955
# Epoch 27/30
# 858/858 [==============================] - 36s 42ms/step - loss: 0.1411 - accuracy: 0.9723 - val_loss: 0.1681 - val_accuracy: 0.9927
# Epoch 28/30
# 858/858 [==============================] - 37s 43ms/step - loss: 0.1562 - accuracy: 0.9710 - val_loss: 0.0758 - val_accuracy: 0.9930
# Epoch 29/30
# 858/858 [==============================] - 37s 43ms/step - loss: 0.1320 - accuracy: 0.9749 - val_loss: 0.4842 - val_accuracy: 0.9936
# Epoch 30/30
# 858/858 [==============================] - 37s 43ms/step - loss: 0.1381 - accuracy: 0.9738 - val_loss: 0.2238 - val_accuracy: 0.9948

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

# %%
test=pd.read_csv(data_dir + '/Test.csv')
test.head()
# Out:
#    Width  Height  Roi.X1  Roi.Y1  Roi.X2  Roi.Y2  ClassId            Path
# 0     53      54       6       5      48      49       16  Test/00000.png
# 1     42      45       5       5      36      40        1  Test/00001.png
# 2     48      52       6       6      43      47       38  Test/00002.png
# 3     27      29       5       5      22      24       33  Test/00003.png
# 4     60      57       5       5      55      52       11  Test/00004.png

# %%
labels=test["ClassId"].values
imgs=test["Path"].values

data=[]

for img in imgs:
    image=cv2.imread(data_dir + '/' + img)
    image_fromarray=Image.fromarray(image,'RGB')
    resize_image=image_fromarray.resize((img_height,img_width))
    data.append(np.array(resize_image))
    
X_test=np.array(data)
X_test=X_test/255

pred=model.predict(X_test)
# Out:
# 395/395 [==============================] - 3s 7ms/step

# %%
categorical_pred = np.argmax(pred, axis=1)
accuracy_score(labels,categorical_pred)
# Out:
# 0.972209026128266

# %%
fig,ax=plt.subplots(3,4)
fig.set_size_inches(16,12)

for i in range(3):
    for j in range (4):
        idx=random.randint(0,42)
        ax[i,j].imshow(X_test[idx])
        if labels[idx] == categorical_pred[idx]:
            ax[i,j].set_title('Actual: '+classes[labels[idx]]+'  \nPredicted: '+classes[categorical_pred[idx]], color = 'green')
        else: 
            ax[i,j].set_title('Actual: '+classes[labels[idx]]+'  \nPredicted: '+classes[categorical_pred[idx]], color = 'red')

plt.tight_layout()
